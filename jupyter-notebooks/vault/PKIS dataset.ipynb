# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as n

import sys
import os
sys.path.insert(0, 'python')

# %%
dirname = os.getcwd()
regression_file = os.path.abspath(os.path.join(dirname, 
                                    'regression_v_1_d_KINASE: GSK Published Kinase Inhibitor Set (PKIS)_p_Kinase Assay.csv'))
regression_df = pd.read_csv(regression_file)
regression_df.sort_values(['GroupName', 'GroupValue'])
# Out:
#                 GroupName                                     GroupValue  \
# 1169   Target (full name)                   ALK tyrosine kinase receptor
# 1170   Target (full name)                   ALK tyrosine kinase receptor
# 1171   Target (full name)                   ALK tyrosine kinase receptor
# 1172   Target (full name)                   ALK tyrosine kinase receptor
# 1173   Target (full name)                   ALK tyrosine kinase receptor
# 1174   Target (full name)                   ALK tyrosine kinase receptor
# 1175   Target (full name)                   ALK tyrosine kinase receptor
# 231    Target (full name)  AMP-activated protein kinase, alpha-1 subunit
# 232    Target (full name)  AMP-activated protein kinase, alpha-1 subunit
# 233    Target (full name)  AMP-activated protein kinase, alpha-1 subunit
# 234    Target (full name)  AMP-activated protein kinase, alpha-1 subunit
# 235    Target (full name)  AMP-activated protein kinase, alpha-1 subunit
# 236    Target (full name)  AMP-activated protein kinase, alpha-1 subunit
# 237    Target (full name)  AMP-activated protein kinase, alpha-1 subunit
# 238    Target (full name)  AMP-activated protein kinase, alpha-2 subunit
# 239    Target (full name)  AMP-activated protein kinase, alpha-2 subunit
# 240    Target (full name)  AMP-activated protein kinase, alpha-2 subunit
# 241    Target (full name)  AMP-activated protein kinase, alpha-2 subunit
# 242    Target (full name)  AMP-activated protein kinase, alpha-2 subunit
# 243    Target (full name)  AMP-activated protein kinase, alpha-2 subunit
# 244    Target (full name)  AMP-activated protein kinase, alpha-2 subunit
# 252    Target (full name)           BR serine/threonine-protein kinase 1
# 253    Target (full name)           BR serine/threonine-protein kinase 1
# 254    Target (full name)           BR serine/threonine-protein kinase 1
# 255    Target (full name)           BR serine/threonine-protein kinase 1
# 256    Target (full name)           BR serine/threonine-protein kinase 1
# 257    Target (full name)           BR serine/threonine-protein kinase 1
# 258    Target (full name)           BR serine/threonine-protein kinase 1
# 259    Target (full name)           BR serine/threonine-protein kinase 2
# 260    Target (full name)           BR serine/threonine-protein kinase 2
# ...                   ...                                            ...
# 1412  Target (short name)                     PKC-beta1 (splice variant)
# 1413  Target (short name)                     PKC-beta1 (splice variant)
# 1414  Target (short name)                     PKC-beta2 (splice variant)
# 1415  Target (short name)                     PKC-beta2 (splice variant)
# 1416  Target (short name)                     PKC-beta2 (splice variant)
# 1417  Target (short name)                     PKC-beta2 (splice variant)
# 1418  Target (short name)                     PKC-beta2 (splice variant)
# 1419  Target (short name)                     PKC-beta2 (splice variant)
# 1420  Target (short name)                     PKC-beta2 (splice variant)
# 1512  Target (short name)                                            RET
# 1513  Target (short name)                                            RET
# 1514  Target (short name)                                            RET
# 1515  Target (short name)                                            RET
# 1516  Target (short name)                                            RET
# 1517  Target (short name)                                            RET
# 1518  Target (short name)                                            RET
# 1519  Target (short name)                             RET (V804L mutant)
# 1520  Target (short name)                             RET (V804L mutant)
# 1521  Target (short name)                             RET (V804L mutant)
# 1522  Target (short name)                             RET (V804L mutant)
# 1523  Target (short name)                             RET (V804L mutant)
# 1524  Target (short name)                             RET (V804L mutant)
# 1525  Target (short name)                             RET (V804L mutant)
# 1526  Target (short name)                             RET (Y791F mutant)
# 1527  Target (short name)                             RET (Y791F mutant)
# 1528  Target (short name)                             RET (Y791F mutant)
# 1529  Target (short name)                             RET (Y791F mutant)
# 1530  Target (short name)                             RET (Y791F mutant)
# 1531  Target (short name)                             RET (Y791F mutant)
# 1532  Target (short name)                             RET (Y791F mutant)
#
#       Size                                      Estimator       RMSE  \
# 1169   364      RBF libSVM folded fingerprints regression  11.542776
# 1170   364         Weka RF folded fingerprints regression   7.903280
# 1171   364  Elastic Net on folded fingerprints regression   7.373175
# 1172   364         Poly Smile SVM fingerprints regression   7.385546
# 1173   364                  Tanimoto Smile SVM regression  14.356152
# 1174   364           RBF Smile SVM descriptors regression  12.630268
# 1175   364                 Weka RF descriptors regression   9.694584
# 231    364                 Weka RF descriptors regression   8.500185
# 232    364         Poly Smile SVM fingerprints regression   8.686056
# 233    364         Weka RF folded fingerprints regression   9.024538
# 234    364           RBF Smile SVM descriptors regression  10.319513
# 235    364  Elastic Net on folded fingerprints regression   8.958274
# 236    364      RBF libSVM folded fingerprints regression  10.316371
# 237    364                  Tanimoto Smile SVM regression  10.805466
# 238    364           RBF Smile SVM descriptors regression   5.554312
# 239    364         Weka RF folded fingerprints regression   5.572195
# 240    364      RBF libSVM folded fingerprints regression   5.684204
# 241    364                  Tanimoto Smile SVM regression   5.791780
# 242    364                 Weka RF descriptors regression   5.733532
# 243    364         Poly Smile SVM fingerprints regression   5.733429
# 244    364  Elastic Net on folded fingerprints regression   6.325172
# 252    364      RBF libSVM folded fingerprints regression   9.250177
# 253    364         Poly Smile SVM fingerprints regression   8.732866
# 254    364                 Weka RF descriptors regression   8.891231
# 255    364         Weka RF folded fingerprints regression   8.850386
# 256    364           RBF Smile SVM descriptors regression   9.764687
# 257    364                  Tanimoto Smile SVM regression   9.828601
# 258    364  Elastic Net on folded fingerprints regression   9.321448
# 259    364         Weka RF folded fingerprints regression  10.007923
# 260    364      RBF libSVM folded fingerprints regression  10.968816
# ...    ...                                            ...        ...
# 1412   364                 Weka RF descriptors regression   7.880616
# 1413   364  Elastic Net on folded fingerprints regression   8.522391
# 1414   364      RBF libSVM folded fingerprints regression   6.118721
# 1415   364           RBF Smile SVM descriptors regression   6.205510
# 1416   364         Weka RF folded fingerprints regression   5.897325
# 1417   364                  Tanimoto Smile SVM regression   6.425922
# 1418   364                 Weka RF descriptors regression   6.091853
# 1419   364         Poly Smile SVM fingerprints regression   6.390208
# 1420   364  Elastic Net on folded fingerprints regression   7.263450
# 1512   364         Poly Smile SVM fingerprints regression  14.296158
# 1513   364         Weka RF folded fingerprints regression  15.239788
# 1514   364  Elastic Net on folded fingerprints regression  16.089284
# 1515   364                 Weka RF descriptors regression  16.131809
# 1516   364      RBF libSVM folded fingerprints regression  18.174016
# 1517   364                  Tanimoto Smile SVM regression  19.359759
# 1518   364           RBF Smile SVM descriptors regression  18.372023
# 1519   364         Poly Smile SVM fingerprints regression  11.383791
# 1520   364         Weka RF folded fingerprints regression  11.890769
# 1521   364                 Weka RF descriptors regression  12.217626
# 1522   364  Elastic Net on folded fingerprints regression  12.432482
# 1523   364      RBF libSVM folded fingerprints regression  13.952319
# 1524   364           RBF Smile SVM descriptors regression  13.689162
# 1525   364                  Tanimoto Smile SVM regression  14.969589
# 1526   364         Poly Smile SVM fingerprints regression  14.050547
# 1527   364         Weka RF folded fingerprints regression  14.718049
# 1528   364  Elastic Net on folded fingerprints regression  15.767032
# 1529   364                 Weka RF descriptors regression  15.469803
# 1530   364      RBF libSVM folded fingerprints regression  17.335188
# 1531   364                  Tanimoto Smile SVM regression  18.290133
# 1532   364           RBF Smile SVM descriptors regression  17.602295
#
#       Correlation
# 1169     0.915898
# 1170     0.905036
# 1171     0.893687
# 1172     0.892114
# 1173     0.846721
# 1174     0.838388
# 1175     0.805350
# 231      0.660966
# 232      0.645052
# 233      0.626236
# 234      0.623882
# 235      0.620725
# 236      0.573277
# 237      0.520010
# 238      0.475986
# 239      0.435172
# 240      0.423423
# 241      0.410164
# 242      0.389591
# 243      0.384204
# 244      0.268363
# 252      0.597586
# 253      0.574881
# 254      0.558445
# 255      0.556703
# 256      0.547547
# 257      0.544474
# 258      0.526691
# 259      0.633645
# 260      0.632095
# ...           ...
# 1412     0.624830
# 1413     0.571128
# 1414     0.534431
# 1415     0.510695
# 1416     0.508271
# 1417     0.473236
# 1418     0.470932
# 1419     0.433602
# 1420     0.320981
# 1512     0.713122
# 1513     0.673995
# 1514     0.629615
# 1515     0.612111
# 1516     0.605949
# 1517     0.556820
# 1518     0.545941
# 1519     0.722889
# 1520     0.703358
# 1521     0.673393
# 1522     0.664207
# 1523     0.631222
# 1524     0.612427
# 1525     0.599553
# 1526     0.692572
# 1527     0.666416
# 1528     0.612935
# 1529     0.609381
# 1530     0.603770
# 1531     0.551142
# 1532     0.515908
#
# [1652 rows x 6 columns]

# %%
max_indices=regression_df.groupby(['GroupName', 'GroupValue'])["Correlation"].idxmax()
best_regression_df=regression_df.loc[max_indices]
best_regression_df.sort_values(['GroupName', 'GroupValue'])
# Out:
#                 GroupName                                         GroupValue  \
# 1169   Target (full name)                       ALK tyrosine kinase receptor
# 231    Target (full name)      AMP-activated protein kinase, alpha-1 subunit
# 238    Target (full name)      AMP-activated protein kinase, alpha-2 subunit
# 252    Target (full name)               BR serine/threonine-protein kinase 1
# 259    Target (full name)               BR serine/threonine-protein kinase 2
# 266    Target (full name)                                 CaM kinase I delta
# 273    Target (full name)                                CaM kinase II alpha
# 280    Target (full name)                                CaM kinase II delta
# 287    Target (full name)                                      CaM kinase IV
# 469    Target (full name)                              Casein kinase I alpha
# 476    Target (full name)                            Casein kinase I gamma 1
# 483    Target (full name)                            Casein kinase I gamma 2
# 490    Target (full name)                    Casein kinase I isoform gamma-3
# 700    Target (full name)                             Casein kinase II alpha
# 497    Target (full name)                          Cyclin-dependent kinase 1
# 504    Target (full name)                          Cyclin-dependent kinase 2
# 511    Target (full name)                          Cyclin-dependent kinase 3
# 518    Target (full name)                          Cyclin-dependent kinase 4
# 525    Target (full name)                          Cyclin-dependent kinase 5
# 532    Target (full name)                          Cyclin-dependent kinase 6
# 308    Target (full name)                  Death-associated protein kinase 1
# 1225   Target (full name)             Discoidin domain-containing receptor 2
# 1092   Target (full name)  Dual specificity mitogen-activated protein kin...
# 539    Target (full name)               Dual specificity protein kinase CLK2
# 546    Target (full name)               Dual specificity protein kinase CLK3
# 770    Target (full name)                Dual specificity protein kinase TTK
# 560    Target (full name)  Dual specificity tyrosine-phosphorylation-regu...
# 553    Target (full name)  Dual-specificity tyrosine-phosphorylation regu...
# 567    Target (full name)  Dual-specificity tyrosine-phosphorylation regu...
# 1239   Target (full name)                           Ephrin type-A receptor 2
# ...                   ...                                                ...
# 1561  Target (short name)                                ABL1 (T315I mutant)
# 1568  Target (short name)                                ABL1 (Y253F mutant)
# 1624  Target (short name)                                               BRAF
# 1631  Target (short name)                                BRAF (V599E mutant)
# 1421  Target (short name)                                       CDK2/cyclinA
# 1428  Target (short name)                                       CDK2/cyclinE
# 1582  Target (short name)                                               EGFR
# 1589  Target (short name)                                EGFR (L858R mutant)
# 1596  Target (short name)                                EGFR (L861Q mutant)
# 1603  Target (short name)                                EGFR (T790M mutant)
# 1610  Target (short name)                          EGFR (T790M-L858R mutant)
# 1617  Target (short name)                                               FLT3
# 1435  Target (short name)                                FLT3 (D835Y mutant)
# 1442  Target (short name)                                                KIT
# 1449  Target (short name)                                 KIT (D816V mutant)
# 1456  Target (short name)                                 KIT (T6701 mutant)
# 1463  Target (short name)                                 KIT (V560G mutant)
# 1638  Target (short name)                                              LRRK2
# 1645  Target (short name)                              LRRK2 (G2019S mutant)
# 1470  Target (short name)                             LYN A (splice variant)
# 1477  Target (short name)                             LYN B (splice variant)
# 1484  Target (short name)                                             PDGFRA
# 1491  Target (short name)                              PDGFRA (D842V mutant)
# 1498  Target (short name)                              PDGFRA (T674I mutant)
# 1505  Target (short name)                              PDGFRA (V561D mutant)
# 1407  Target (short name)                         PKC-beta1 (splice variant)
# 1414  Target (short name)                         PKC-beta2 (splice variant)
# 1512  Target (short name)                                                RET
# 1519  Target (short name)                                 RET (V804L mutant)
# 1526  Target (short name)                                 RET (Y791F mutant)
#
#       Size                                  Estimator       RMSE  Correlation
# 1169   364  RBF libSVM folded fingerprints regression  11.542776     0.915898
# 231    364             Weka RF descriptors regression   8.500185     0.660966
# 238    364       RBF Smile SVM descriptors regression   5.554312     0.475986
# 252    364  RBF libSVM folded fingerprints regression   9.250177     0.597586
# 259    364     Weka RF folded fingerprints regression  10.007923     0.633645
# 266    364             Weka RF descriptors regression   3.436095     0.635093
# 273    364             Weka RF descriptors regression   3.611374     0.394350
# 280    364     Poly Smile SVM fingerprints regression   5.544865     0.598695
# 287    364     Weka RF folded fingerprints regression   2.735180     0.577199
# 469    364     Weka RF folded fingerprints regression   8.582094     0.727684
# 476    364             Weka RF descriptors regression   4.859653     0.586466
# 483    364     Weka RF folded fingerprints regression   5.076959     0.595728
# 490    364     Weka RF folded fingerprints regression   6.152928     0.636961
# 700    364     Weka RF folded fingerprints regression   6.996060     0.631268
# 497    364     Weka RF folded fingerprints regression  10.576756     0.732360
# 504    364     Poly Smile SVM fingerprints regression  11.663485     0.802870
# 511    364     Poly Smile SVM fingerprints regression  10.793911     0.761805
# 518    364     Poly Smile SVM fingerprints regression   8.345717     0.760097
# 525    364     Poly Smile SVM fingerprints regression  10.723653     0.732208
# 532    364     Poly Smile SVM fingerprints regression  10.586994     0.701752
# 308    364             Weka RF descriptors regression   5.566118     0.178621
# 1225   364     Weka RF folded fingerprints regression   9.732631     0.816683
# 1092   364     Poly Smile SVM fingerprints regression   4.912663     0.501919
# 539    364     Poly Smile SVM fingerprints regression  11.488299     0.814932
# 546    364     Poly Smile SVM fingerprints regression   5.627101     0.580306
# 770    364     Weka RF folded fingerprints regression  10.503090     0.685186
# 560    364     Poly Smile SVM fingerprints regression   9.574503     0.806418
# 553    364     Poly Smile SVM fingerprints regression  10.789909     0.762966
# 567    364     Poly Smile SVM fingerprints regression   6.963260     0.492205
# 1239   364     Weka RF folded fingerprints regression  10.884051     0.534364
# ...    ...                                        ...        ...          ...
# 1561   364     Poly Smile SVM fingerprints regression  11.245986     0.703021
# 1568   364     Poly Smile SVM fingerprints regression  13.227645     0.772460
# 1624   364     Poly Smile SVM fingerprints regression   6.665612     0.668553
# 1631   364     Poly Smile SVM fingerprints regression   6.462414     0.711092
# 1421   364     Poly Smile SVM fingerprints regression  13.047038     0.794368
# 1428   364     Poly Smile SVM fingerprints regression  10.726876     0.800350
# 1582   364     Poly Smile SVM fingerprints regression   9.457163     0.919232
# 1589   364     Poly Smile SVM fingerprints regression  13.385129     0.781989
# 1596   364     Poly Smile SVM fingerprints regression   9.950686     0.840531
# 1603   364     Weka RF folded fingerprints regression   5.422779     0.710095
# 1610   364     Poly Smile SVM fingerprints regression   7.660990     0.731156
# 1617   364     Weka RF folded fingerprints regression  12.718508     0.756014
# 1435   364     Poly Smile SVM fingerprints regression  11.582025     0.636797
# 1442   364     Poly Smile SVM fingerprints regression  16.991655     0.777008
# 1449   364     Poly Smile SVM fingerprints regression   6.401520     0.419735
# 1456   364     Poly Smile SVM fingerprints regression  11.087127     0.744073
# 1463   364     Poly Smile SVM fingerprints regression   9.951945     0.828234
# 1638   364     Poly Smile SVM fingerprints regression   9.809840     0.726506
# 1645   364     Poly Smile SVM fingerprints regression   9.696695     0.792846
# 1470   364     Poly Smile SVM fingerprints regression  11.571198     0.689618
# 1477   364     Poly Smile SVM fingerprints regression  10.909817     0.691085
# 1484   364     Poly Smile SVM fingerprints regression  14.428003     0.730524
# 1491   364     Poly Smile SVM fingerprints regression  14.510431     0.660374
# 1498   364     Poly Smile SVM fingerprints regression  13.866386     0.711027
# 1505   364     Poly Smile SVM fingerprints regression  15.800364     0.756596
# 1407   364  RBF libSVM folded fingerprints regression   8.035424     0.700700
# 1414   364  RBF libSVM folded fingerprints regression   6.118721     0.534431
# 1512   364     Poly Smile SVM fingerprints regression  14.296158     0.713122
# 1519   364     Poly Smile SVM fingerprints regression  11.383791     0.722889
# 1526   364     Poly Smile SVM fingerprints regression  14.050547     0.692572
#
# [236 rows x 6 columns]

# %%
best_regression_df['Correlation'].describe()
# Out:
# count    236.000000
# mean       0.615214
# std        0.188093
# min       -0.003559
# 25%        0.531956
# 50%        0.656054
# 75%        0.743578
# max        0.921254
# Name: Correlation, dtype: float64

# %%
best_regression_df['RMSE'].describe()
# Out:
# count    236.000000
# mean       8.427263
# std        3.341966
# min        1.451942
# 25%        6.084174
# 50%        8.478793
# 75%       10.884625
# max       18.306004
# Name: RMSE, dtype: float64

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14, 7))
sns.distplot(best_regression_df['Correlation'], rug=True, kde=True, ax=axes[0])
sns.distplot(best_regression_df['RMSE'], rug=True, kde=True, ax=axes[1])

# %%
best_regression_df['Estimator'].value_counts()
# Out:
# Poly Smile SVM fingerprints regression           117
# Weka RF folded fingerprints regression            53
# Weka RF descriptors regression                    25
# RBF libSVM folded fingerprints regression         24
# RBF Smile SVM descriptors regression              10
# Tanimoto Smile SVM regression                      4
# Elastic Net on folded fingerprints regression      3
# Name: Estimator, dtype: int64

# %%
sns.countplot(y='Estimator', data=best_regression_df)

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(14, 7))
sns.boxplot(y='Estimator', x='Correlation', data=regression_df, ax=axes)
#for tick in axes.get_xticklabels():
#    tick.set_rotation(80)

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(14, 7))
sns.boxplot(x='Estimator', y='RMSE', data=regression_df, ax=axes)
for tick in axes.get_xticklabels():
    tick.set_rotation(80)

# %%
dirname = os.getcwd()
classification_file = os.path.abspath(os.path.join(dirname, 
                                    'classification_v_1_d_KINASE: GSK Published Kinase Inhibitor Set (PKIS)_p_Kinase Assay.csv'))
classification_df = pd.read_csv(classification_file)
classification_df.sort_values(['GroupName', 'GroupValue'])
# Out:
#                 GroupName                                     GroupValue  \
# 1002   Target (full name)                   ALK tyrosine kinase receptor
# 1003   Target (full name)                   ALK tyrosine kinase receptor
# 1004   Target (full name)                   ALK tyrosine kinase receptor
# 1005   Target (full name)                   ALK tyrosine kinase receptor
# 1006   Target (full name)                   ALK tyrosine kinase receptor
# 1007   Target (full name)                   ALK tyrosine kinase receptor
# 198    Target (full name)  AMP-activated protein kinase, alpha-1 subunit
# 199    Target (full name)  AMP-activated protein kinase, alpha-1 subunit
# 200    Target (full name)  AMP-activated protein kinase, alpha-1 subunit
# 201    Target (full name)  AMP-activated protein kinase, alpha-1 subunit
# 202    Target (full name)  AMP-activated protein kinase, alpha-1 subunit
# 203    Target (full name)  AMP-activated protein kinase, alpha-1 subunit
# 204    Target (full name)  AMP-activated protein kinase, alpha-2 subunit
# 205    Target (full name)  AMP-activated protein kinase, alpha-2 subunit
# 206    Target (full name)  AMP-activated protein kinase, alpha-2 subunit
# 207    Target (full name)  AMP-activated protein kinase, alpha-2 subunit
# 208    Target (full name)  AMP-activated protein kinase, alpha-2 subunit
# 209    Target (full name)  AMP-activated protein kinase, alpha-2 subunit
# 216    Target (full name)           BR serine/threonine-protein kinase 1
# 217    Target (full name)           BR serine/threonine-protein kinase 1
# 218    Target (full name)           BR serine/threonine-protein kinase 1
# 219    Target (full name)           BR serine/threonine-protein kinase 1
# 220    Target (full name)           BR serine/threonine-protein kinase 1
# 221    Target (full name)           BR serine/threonine-protein kinase 1
# 222    Target (full name)           BR serine/threonine-protein kinase 2
# 223    Target (full name)           BR serine/threonine-protein kinase 2
# 224    Target (full name)           BR serine/threonine-protein kinase 2
# 225    Target (full name)           BR serine/threonine-protein kinase 2
# 226    Target (full name)           BR serine/threonine-protein kinase 2
# 227    Target (full name)           BR serine/threonine-protein kinase 2
# ...                   ...                                            ...
# 1206  Target (short name)                     PKC-beta1 (splice variant)
# 1207  Target (short name)                     PKC-beta1 (splice variant)
# 1208  Target (short name)                     PKC-beta1 (splice variant)
# 1209  Target (short name)                     PKC-beta1 (splice variant)
# 1210  Target (short name)                     PKC-beta1 (splice variant)
# 1211  Target (short name)                     PKC-beta1 (splice variant)
# 1212  Target (short name)                     PKC-beta2 (splice variant)
# 1213  Target (short name)                     PKC-beta2 (splice variant)
# 1214  Target (short name)                     PKC-beta2 (splice variant)
# 1215  Target (short name)                     PKC-beta2 (splice variant)
# 1216  Target (short name)                     PKC-beta2 (splice variant)
# 1217  Target (short name)                     PKC-beta2 (splice variant)
# 1296  Target (short name)                                            RET
# 1297  Target (short name)                                            RET
# 1298  Target (short name)                                            RET
# 1299  Target (short name)                                            RET
# 1300  Target (short name)                                            RET
# 1301  Target (short name)                                            RET
# 1302  Target (short name)                             RET (V804L mutant)
# 1303  Target (short name)                             RET (V804L mutant)
# 1304  Target (short name)                             RET (V804L mutant)
# 1305  Target (short name)                             RET (V804L mutant)
# 1306  Target (short name)                             RET (V804L mutant)
# 1307  Target (short name)                             RET (V804L mutant)
# 1308  Target (short name)                             RET (Y791F mutant)
# 1309  Target (short name)                             RET (Y791F mutant)
# 1310  Target (short name)                             RET (Y791F mutant)
# 1311  Target (short name)                             RET (Y791F mutant)
# 1312  Target (short name)                             RET (Y791F mutant)
# 1313  Target (short name)                             RET (Y791F mutant)
#
#       Size                            Estimator   ROC_AUC Direction  Threshold
# 1002   364    Smile SVC Tanimoto classification  0.859883        UP    11.4975
# 1003   364        Smile SVC Poly classification  0.844893        UP    11.4975
# 1004   364    Smile Bernoulli NB classification  0.818428        UP    11.4975
# 1005   364  Weka RF on folded fp classification  0.817920        UP    11.4975
# 1006   364         Smile SVC RBF classification  0.787898        UP    11.4975
# 1007   364               Weka RF classification  0.748137        UP    11.4975
# 198    364               Weka RF classification  0.918064        UP    12.7525
# 199    364         Smile SVC RBF classification  0.903540        UP    12.7525
# 200    364  Weka RF on folded fp classification  0.901296        UP    12.7525
# 201    364    Smile Bernoulli NB classification  0.872417        UP    12.7525
# 202    364    Smile SVC Tanimoto classification  0.861365        UP    12.7525
# 203    364        Smile SVC Poly classification  0.843750        UP    12.7525
# 204    364        Smile SVC Poly classification  0.856199        UP     7.9175
# 205    364    Smile Bernoulli NB classification  0.853659        UP     7.9175
# 206    364  Weka RF on folded fp classification  0.852219        UP     7.9175
# 207    364               Weka RF classification  0.840828        UP     7.9175
# 208    364    Smile SVC Tanimoto classification  0.832995        UP     7.9175
# 209    364         Smile SVC RBF classification  0.763974        UP     7.9175
# 216    364  Weka RF on folded fp classification  0.905954        UP    12.6325
# 217    364    Smile Bernoulli NB classification  0.900999        UP    12.6325
# 218    364               Weka RF classification  0.893039        UP    12.6325
# 219    364        Smile SVC Poly classification  0.884485        UP    12.6325
# 220    364    Smile SVC Tanimoto classification  0.879234        UP    12.6325
# 221    364         Smile SVC RBF classification  0.804031        UP    12.6325
# 222    364    Smile SVC Tanimoto classification  0.907012        UP    17.3075
# 223    364    Smile Bernoulli NB classification  0.904641        UP    17.3075
# 224    364  Weka RF on folded fp classification  0.892954        UP    17.3075
# 225    364        Smile SVC Poly classification  0.889990        UP    17.3075
# 226    364               Weka RF classification  0.850652        UP    17.3075
# 227    364         Smile SVC RBF classification  0.808096        UP    17.3075
# ...    ...                                  ...       ...       ...        ...
# 1206   364    Smile Bernoulli NB classification  0.886433        UP     8.1050
# 1207   364               Weka RF classification  0.870469        UP     8.1050
# 1208   364  Weka RF on folded fp classification  0.857088        UP     8.1050
# 1209   364    Smile SVC Tanimoto classification  0.808350        UP     8.1050
# 1210   364        Smile SVC Poly classification  0.756944        UP     8.1050
# 1211   364         Smile SVC RBF classification  0.751524        UP     8.1050
# 1212   364         Smile SVC RBF classification  0.853320        UP     6.7975
# 1213   364  Weka RF on folded fp classification  0.821604        UP     6.7975
# 1214   364    Smile Bernoulli NB classification  0.817497        UP     6.7975
# 1215   364               Weka RF classification  0.815845        UP     6.7975
# 1216   364        Smile SVC Poly classification  0.785738        UP     6.7975
# 1217   364    Smile SVC Tanimoto classification  0.783367        UP     6.7975
# 1296   364  Weka RF on folded fp classification  0.878811        UP    44.6525
# 1297   364    Smile Bernoulli NB classification  0.871824        UP    44.6525
# 1298   364    Smile SVC Tanimoto classification  0.860349        UP    44.6525
# 1299   364        Smile SVC Poly classification  0.837822        UP    44.6525
# 1300   364               Weka RF classification  0.811907        UP    44.6525
# 1301   364         Smile SVC RBF classification  0.785738        UP    44.6525
# 1302   364  Weka RF on folded fp classification  0.916032        UP    34.2625
# 1303   364    Smile SVC Tanimoto classification  0.914804        UP    34.2625
# 1304   364         Smile SVC RBF classification  0.907605        UP    34.2625
# 1305   364        Smile SVC Poly classification  0.904895        UP    34.2625
# 1306   364               Weka RF classification  0.893420        UP    34.2625
# 1307   364    Smile Bernoulli NB classification  0.891853        UP    34.2625
# 1308   364    Smile Bernoulli NB classification  0.888847        UP    48.3400
# 1309   364    Smile SVC Tanimoto classification  0.831386        UP    48.3400
# 1310   364  Weka RF on folded fp classification  0.806360        UP    48.3400
# 1311   364               Weka RF classification  0.805979        UP    48.3400
# 1312   364         Smile SVC RBF classification  0.783537        UP    48.3400
# 1313   364        Smile SVC Poly classification  0.757453        UP    48.3400
#
# [1416 rows x 7 columns]

# %%
max_indices=classification_df.groupby(['GroupName', 'GroupValue'])["ROC_AUC"].idxmax()
best_classification_df=classification_df.loc[max_indices]
best_classification_df.sort_values(['GroupName', 'GroupValue'])
# Out:
#                 GroupName                                         GroupValue  \
# 1002   Target (full name)                       ALK tyrosine kinase receptor
# 198    Target (full name)      AMP-activated protein kinase, alpha-1 subunit
# 204    Target (full name)      AMP-activated protein kinase, alpha-2 subunit
# 216    Target (full name)               BR serine/threonine-protein kinase 1
# 222    Target (full name)               BR serine/threonine-protein kinase 2
# 228    Target (full name)                                 CaM kinase I delta
# 234    Target (full name)                                CaM kinase II alpha
# 240    Target (full name)                                CaM kinase II delta
# 246    Target (full name)                                      CaM kinase IV
# 402    Target (full name)                              Casein kinase I alpha
# 408    Target (full name)                            Casein kinase I gamma 1
# 414    Target (full name)                            Casein kinase I gamma 2
# 420    Target (full name)                    Casein kinase I isoform gamma-3
# 600    Target (full name)                             Casein kinase II alpha
# 426    Target (full name)                          Cyclin-dependent kinase 1
# 432    Target (full name)                          Cyclin-dependent kinase 2
# 438    Target (full name)                          Cyclin-dependent kinase 3
# 444    Target (full name)                          Cyclin-dependent kinase 4
# 450    Target (full name)                          Cyclin-dependent kinase 5
# 456    Target (full name)                          Cyclin-dependent kinase 6
# 264    Target (full name)                  Death-associated protein kinase 1
# 1050   Target (full name)             Discoidin domain-containing receptor 2
# 936    Target (full name)  Dual specificity mitogen-activated protein kin...
# 462    Target (full name)               Dual specificity protein kinase CLK2
# 468    Target (full name)               Dual specificity protein kinase CLK3
# 660    Target (full name)                Dual specificity protein kinase TTK
# 480    Target (full name)  Dual specificity tyrosine-phosphorylation-regu...
# 474    Target (full name)  Dual-specificity tyrosine-phosphorylation regu...
# 486    Target (full name)  Dual-specificity tyrosine-phosphorylation regu...
# 1062   Target (full name)                           Ephrin type-A receptor 2
# ...                   ...                                                ...
# 1338  Target (short name)                                ABL1 (T315I mutant)
# 1344  Target (short name)                                ABL1 (Y253F mutant)
# 1392  Target (short name)                                               BRAF
# 1398  Target (short name)                                BRAF (V599E mutant)
# 1218  Target (short name)                                       CDK2/cyclinA
# 1224  Target (short name)                                       CDK2/cyclinE
# 1356  Target (short name)                                               EGFR
# 1362  Target (short name)                                EGFR (L858R mutant)
# 1368  Target (short name)                                EGFR (L861Q mutant)
# 1374  Target (short name)                                EGFR (T790M mutant)
# 1380  Target (short name)                          EGFR (T790M-L858R mutant)
# 1386  Target (short name)                                               FLT3
# 1230  Target (short name)                                FLT3 (D835Y mutant)
# 1236  Target (short name)                                                KIT
# 1242  Target (short name)                                 KIT (D816V mutant)
# 1248  Target (short name)                                 KIT (T6701 mutant)
# 1254  Target (short name)                                 KIT (V560G mutant)
# 1404  Target (short name)                                              LRRK2
# 1410  Target (short name)                              LRRK2 (G2019S mutant)
# 1260  Target (short name)                             LYN A (splice variant)
# 1266  Target (short name)                             LYN B (splice variant)
# 1272  Target (short name)                                             PDGFRA
# 1278  Target (short name)                              PDGFRA (D842V mutant)
# 1284  Target (short name)                              PDGFRA (T674I mutant)
# 1290  Target (short name)                              PDGFRA (V561D mutant)
# 1206  Target (short name)                         PKC-beta1 (splice variant)
# 1212  Target (short name)                         PKC-beta2 (splice variant)
# 1296  Target (short name)                                                RET
# 1302  Target (short name)                                 RET (V804L mutant)
# 1308  Target (short name)                                 RET (Y791F mutant)
#
#       Size                            Estimator   ROC_AUC Direction  Threshold
# 1002   364    Smile SVC Tanimoto classification  0.859883        UP   11.49750
# 198    364               Weka RF classification  0.918064        UP   12.75250
# 204    364        Smile SVC Poly classification  0.856199        UP    7.91750
# 216    364  Weka RF on folded fp classification  0.905954        UP   12.63250
# 222    364    Smile SVC Tanimoto classification  0.907012        UP   17.30750
# 228    364    Smile SVC Tanimoto classification  0.785357        UP    3.44250
# 234    364  Weka RF on folded fp classification  0.709900        UP    5.58000
# 240    364               Weka RF classification  0.782309        UP    9.22750
# 246    364               Weka RF classification  0.699610        UP    2.84500
# 402    364  Weka RF on folded fp classification  0.928946        UP   17.89000
# 408    364        Smile SVC Poly classification  0.869284        UP    7.16750
# 414    364    Smile Bernoulli NB classification  0.847307        UP    6.81750
# 420    364               Weka RF classification  0.881098        UP    8.78625
# 600    364    Smile Bernoulli NB classification  0.883638        UP   13.93500
# 426    364    Smile Bernoulli NB classification  0.932588        UP   16.25250
# 432    364               Weka RF classification  0.939490        UP   25.15125
# 438    364  Weka RF on folded fp classification  0.911966        UP   15.64750
# 444    364    Smile SVC Tanimoto classification  0.947832        UP   16.46250
# 450    364    Smile Bernoulli NB classification  0.904556        UP   19.84250
# 456    364  Weka RF on folded fp classification  0.952109        UP   27.79750
# 264    364    Smile Bernoulli NB classification  0.591633        UP    9.03000
# 1050   364  Weka RF on folded fp classification  0.889778        UP   17.78500
# 936    364  Weka RF on folded fp classification  0.844131        UP    7.55500
# 462    364    Smile SVC Tanimoto classification  0.904980        UP   29.47500
# 468    364    Smile Bernoulli NB classification  0.803184        UP    5.57500
# 660    364  Weka RF on folded fp classification  0.950627        UP   20.60250
# 480    364  Weka RF on folded fp classification  0.938050        UP   23.54250
# 474    364  Weka RF on folded fp classification  0.886433        UP   28.74750
# 486    364               Weka RF classification  0.846799        UP   10.29000
# 1062   364        Smile SVC Poly classification  0.877541        UP    8.97000
# ...    ...                                  ...       ...       ...        ...
# 1338   364  Weka RF on folded fp classification  0.835959        UP   29.63500
# 1344   364  Weka RF on folded fp classification  0.922722        UP   45.61250
# 1392   364        Smile SVC Poly classification  0.896765        UP   13.39250
# 1398   364        Smile SVC Poly classification  0.878811        UP   13.22250
# 1218   364  Weka RF on folded fp classification  0.965617        UP   27.78250
# 1224   364    Smile SVC Tanimoto classification  0.953760        UP   21.17625
# 1356   364  Weka RF on folded fp classification  0.978955        UP   65.41500
# 1362   364  Weka RF on folded fp classification  0.955073        UP   44.83250
# 1368   364    Smile SVC Tanimoto classification  0.960196        UP   33.76000
# 1374   364  Weka RF on folded fp classification  0.933774        UP    6.13750
# 1380   364    Smile Bernoulli NB classification  0.838669        UP    7.38750
# 1386   364  Weka RF on folded fp classification  0.905784        UP   42.46000
# 1230   364  Weka RF on folded fp classification  0.894013        UP   25.82500
# 1236   364    Smile Bernoulli NB classification  0.896765        UP   66.54500
# 1242   364         Smile SVC RBF classification  0.664549        UP    6.89000
# 1248   364  Weka RF on folded fp classification  0.909172        UP   29.29250
# 1254   364  Weka RF on folded fp classification  0.952786        UP   28.53500
# 1404   364               Weka RF classification  0.789084        UP   15.82250
# 1410   364    Smile SVC Tanimoto classification  0.908283        UP   34.21750
# 1260   364  Weka RF on folded fp classification  0.876948        UP   34.50000
# 1266   364  Weka RF on folded fp classification  0.876948        UP   29.75250
# 1272   364    Smile SVC Tanimoto classification  0.883808        UP   55.04750
# 1278   364               Weka RF classification  0.833122        UP   42.04750
# 1284   364  Weka RF on folded fp classification  0.852685        UP   44.29500
# 1290   364  Weka RF on folded fp classification  0.868394        UP   57.89000
# 1206   364    Smile Bernoulli NB classification  0.886433        UP    8.10500
# 1212   364         Smile SVC RBF classification  0.853320        UP    6.79750
# 1296   364  Weka RF on folded fp classification  0.878811        UP   44.65250
# 1302   364  Weka RF on folded fp classification  0.916032        UP   34.26250
# 1308   364    Smile Bernoulli NB classification  0.888847        UP   48.34000
#
# [236 rows x 7 columns]

# %%
best_classification_df['ROC_AUC'].describe()
# Out:
# count    236.000000
# mean       0.841171
# std        0.097178
# min        0.534892
# 25%        0.794906
# 50%        0.871126
# 75%        0.905975
# max        0.978955
# Name: ROC_AUC, dtype: float64

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(7, 7))
sns.distplot(best_classification_df['ROC_AUC'], rug=True, kde=True, ax=axes)

# %%
best_classification_df['Estimator'].value_counts()
# Out:
# Weka RF on folded fp classification    74
# Smile Bernoulli NB classification      55
# Smile SVC Tanimoto classification      39
# Weka RF classification                 30
# Smile SVC Poly classification          25
# Smile SVC RBF classification           13
# Name: Estimator, dtype: int64

# %%
sns.countplot(y='Estimator', data=best_classification_df)

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(14, 7))
sns.boxplot(y='Estimator', x='ROC_AUC', data=classification_df, ax=axes)
