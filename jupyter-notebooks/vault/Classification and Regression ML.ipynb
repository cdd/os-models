# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import re
import os
import math

import seaborn as sns

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#file = 'classification_and_regression_ml.csv'
file = 'opt_classification_and_regression_ml.csv'

dirname = os.getcwd()
classification_file = os.path.abspath(os.path.join(dirname, file))
df = pd.read_csv(classification_file)

# %%
df
# Out:
#                          Estimator        f1   ROC_AUC  Accuracy  TP  FP   TN  \
# 0  Smile SVC Linear classification  0.845238  0.981508  0.919255  71  18  225
# 1           Weka RF classification  0.842105  0.968276  0.925466  64   9  234
# 2     Smile SVC RBF classification  0.829932  0.979841  0.922360  61   7  236
# 3    Smile SVC Poly classification  0.828947  0.975830  0.919255  63  10  233
# 4     Smile SVC RBF classification  0.857143  0.980935  0.934783  63   5  238
# 5           Weka RF classification  0.842105  0.968276  0.925466  64   9  234
# 6  Smile SVC Linear classification  0.830189  0.977965  0.916149  66  14  229
# 7    Smile SVC Poly classification  0.805031  0.973694  0.903727  64  16  227
#
#    FN    Recall  Precision              Category
# 0   8  0.898734   0.797753      BothIsRegression
# 1  15  0.810127   0.876712      BothIsRegression
# 2  18  0.772152   0.897059      BothIsRegression
# 3  16  0.797468   0.863014      BothIsRegression
# ...

# %%
df[df.Category== 'BothIsRegression']
# Out:
#                          Estimator        f1   ROC_AUC  Accuracy  TP  FP   TN  \
# 0  Smile SVC Linear classification  0.845238  0.981508  0.919255  71  18  225
# 1           Weka RF classification  0.842105  0.968276  0.925466  64   9  234
# 2     Smile SVC RBF classification  0.829932  0.979841  0.922360  61   7  236
# 3    Smile SVC Poly classification  0.828947  0.975830  0.919255  63  10  233
#
#    FN    Recall  Precision          Category
# 0   8  0.898734   0.797753  BothIsRegression
# 1  15  0.810127   0.876712  BothIsRegression
# 2  18  0.772152   0.897059  BothIsRegression
# 3  16  0.797468   0.863014  BothIsRegression

# %%
df[df.Category== 'BothIsClassification']
# Out:
#                          Estimator        f1   ROC_AUC  Accuracy  TP  FP   TN  \
# 4     Smile SVC RBF classification  0.857143  0.980935  0.934783  63   5  238
# 5           Weka RF classification  0.842105  0.968276  0.925466  64   9  234
# 6  Smile SVC Linear classification  0.830189  0.977965  0.916149  66  14  229
# 7    Smile SVC Poly classification  0.805031  0.973694  0.903727  64  16  227
#
#    FN    Recall  Precision              Category
# 4  16  0.797468   0.926471  BothIsClassification
# 5  15  0.810127   0.876712  BothIsClassification
# 6  13  0.835443   0.825000  BothIsClassification
# 7  15  0.810127   0.800000  BothIsClassification

# %%
df.to_clipboard()
